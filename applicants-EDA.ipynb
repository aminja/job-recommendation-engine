# %% [markdown]
# ### Exploratory data analysis of job applicants
#
# The goal is to explore the nature and data of the applicants.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

applicants = pd.read_csv('data/Experience.csv')

applicants.head(5)
# Out:
#    Applicant.ID                                      Position.Name  \
# 0         10001  Account Manager / Sales Administration / Quali...
# 1         10001    Electronics Technician / Item Master Controller
# 2         10001                                   Machine Operator
# 3         10003                             maintenance technician
# 4         10003                                 Electrical Helper
#
#                Employer.Name         City            State.Name State.Code  \
# 0         Barcode Resourcing   Bellingham            Washington         WA
# 1       Ryzpositionsex Group   Bellingham            Washington         WA
# 2                comptec inc       Custer            Washington         WA
# 3           Winn residental    washington  District of Columbia         DC
# 4  michael and son services   alexandria               Virginia         VA
#
#    Start.Date    End.Date                                    Job.Description  \
# ...

# %%
# check overall view of columns

applicants.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8653 entries, 0 to 8652
# Data columns (total 13 columns):
# Applicant.ID            8653 non-null int64
# Position.Name           7703 non-null object
# Employer.Name           8620 non-null object
# City                    4922 non-null object
# State.Name              4595 non-null object
# State.Code              4595 non-null object
# Start.Date              6618 non-null object
# End.Date                4906 non-null object
# Job.Description         5692 non-null object
# Salary                  2798 non-null float64
# Can.Contact.Employer    3581 non-null object
# Created.At              8653 non-null object
# Updated.At              8653 non-null object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 878.9+ KB

# %%
# Get an overview of applicant's job title

applicants['Position.Name'].value_counts()
# Out:
# Cashier                                               129
# Sales Associate                                       116
# Server                                                 86
# Administrative Assistant                               76
# Owner                                                  58
#                                                      ...
# volunteer pol worker                                    1
# Teachers Aide                                           1
# MPLSM-Multipurpose Letter Sorting Machine Operator      1
# Farm Intern                                             1
# Retail Lead  at   a Casino                              1
# Name: Position.Name, Length: 4986, dtype: int64
